# %% [markdown]
# Jane-Street-Puzzle-Apr-2024

# %% [markdown]
# Here is my solution for the April 2024 Jane Street Puzzle. You can find the description here: https://www.janestreet.com/puzzles/robot-capture-the-flag-index/

# %% [markdown]
# I managed to make the leaderboard this month ![image.png](attachment:d975fa80-740a-4dff-a451-d209b81f9ac8.png)

# %% [raw]
# Here is my solution:

# %% [markdown]
# ![image.png](attachment:d05a6e3c-f199-4558-8ba9-817abc719cf0.png)

# %% [markdown]
# ![image.png](attachment:1cdcc428-da78-4b13-a0a3-014391be9e41.png)

# %% [markdown]
# ![image.png](attachment:187f0839-3e88-4522-be13-7139b294663b.png)

# %% [markdown]
# ![image.png](attachment:9782d396-e2d2-4d29-b635-598be0c6b297.png)

# %% [raw]
# This is the code used to find the optimal Pwin

# %% [raw]
# import numpy as np
# from scipy.optimize import minimize
#
# def P_win(r):
#     return (np.arcsin(1-r)-1/3*np.sqrt(r)*(r+1)*np.sqrt(2-r)+2/3*r**2+1/3*2*r*r-r**2*np.arcsin(1)/4)/np.pi+r**2/4
#
# # Define bounds for r
# bounds = [(0, 1)]
#
# # Use minimize to find the minimum within the bounds
# result = minimize(P_win, x0=0.5, bounds=bounds)
#
# print("Minimum value of P_win:", result.fun)
# print("Value of r at minimum:", result.x)
